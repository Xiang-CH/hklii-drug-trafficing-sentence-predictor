# %% [markdown]
# # Verified-charge factor and outlier workbook
#
# This notebook reads verified sentencing records and writes `sentencing_factor_outlier_lists.xlsx`. It creates standard charge lists for the requested drug and factor values, plus one classified plea-outlier sheet and one classified assistance-outlier sheet. It does not write to MongoDB.
#
# Inferred sentence data is included throughout the workbook and is identified by `*_inferred` columns. Records with a relevant plea or assistance factor but insufficient quantitative data are counted in the workbook summary and are not labelled as outliers.

# %%
from sentencing_factor_outlier_lists import main

summary = main()
summary
